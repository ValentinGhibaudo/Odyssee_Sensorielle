# %%
import numpy as np
import json
import pandas as pd
import glob
import matplotlib.pyplot as plt
from params import *

# %%
save = False

# %%
def get_sec(time_str): # get seconds from time 
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

# %%
timestamps_files = glob.glob('../data/timestamps_*/*')

# %%
timestamps_files
# Out:
# ['../data/timestamps_ses_01/P06PHERAX_2022-05-12 12 29 50.json',
#  '../data/timestamps_ses_01/P05PROZEM_2022-05-12 11 58 48.json',
#  '../data/timestamps_ses_01/P01PPILNI_2022-05-12 10 41 43.json',
#  '../data/timestamps_ses_01/P04PROMCH_2022-05-12 12 28 16.json',
#  '../data/timestamps_ses_01/P03PBABCO_2022-05-12 11 17 55.json',
#  '../data/timestamps_ses_04/P19MONAL (1)  1_2022-06-02 10 35 52.json',
#  '../data/timestamps_ses_04/P20POUAX (4)  AZERTY_2022-06-02 10 46 47.json',
#  '../data/timestamps_ses_04/P22DALPI (3) 3_2022-06-02 11 30 42.json',
#  '../data/timestamps_ses_04/P23VIVBA (1)  1_2022-06-02 12 00 15.json',
#  '../data/timestamps_ses_04/P21LIYAT (2) romain_2022-06-02 11 35 57.json',
#  '../data/timestamps_ses_05/P27OSTMA (3) _2022-06-09 11 22 46.json',
#  '../data/timestamps_ses_05/P25PEIAN (1) 1_2022-06-09 11 01 54.json',
#  '../data/timestamps_ses_05/P29FICMA (1) 1_2022-06-09 12 26 16.json',
#  '../data/timestamps_ses_05/P28JUDGU (4) 3_2022-06-09 11 35 13.json',
#  '../data/timestamps_ses_05/P26BOUME (2) 2_2022-06-09 11 07 37.json',
#  '../data/timestamps_ses_05/P30BATDI (2) 2_2022-06-09 12 45 31.json',
#  '../data/timestamps_ses_02/P08AKKOR_2022-05-19 10 54 09.json',
#  '../data/timestamps_ses_02/P07GHOLE_2022-05-19 10 38 51.json',
#  '../data/timestamps_ses_02/P09COUAM_2022-05-19 11 18 20.json',
#  '../data/timestamps_ses_02/P12BOULI_2022-05-19 12 05 20.json',
#  '../data/timestamps_ses_02/P11KERSA_2022-05-19 11 53 54.json',
#  '../data/timestamps_ses_02/P10LEVVA_2022-05-19 11 33 06.json',
#  '../data/timestamps_ses_03/P14BENLA 10h14 -05-23 11 23 24.json',
#  '../data/timestamps_ses_03/P15LEPMA 10h00 3_2022-05-23 10_59_49.json',
#  '../data/timestamps_ses_03/P17ETRPA 11h01 2_2022-05-23 12_08_22.json',
#  '../data/timestamps_ses_03/P16MAUAD 10h41 1_2022-05-23 11_43_13.json',
#  '../data/timestamps_ses_03/P13MORMA 9h45 1_2022-05-23 10_37_15.json',
#  '../data/timestamps_ses_03/P18BLAMA 11h19 3_2022-05-23 11_59_18.json']

# %%
rows = []
for file in timestamps_files:

    with open(file, 'r') as f:
        data = json.load(f)
    df_p = pd.DataFrame.from_dict(data, orient = 'index').T

    substraction = get_sec(df_p.iloc[0, 2].split(' ')[1]) # datetime in secs of t0_in (start baseline)

    for i in range(2, df_p.size, 2): # loop from t0_in to t8_in by step = 2 to get only t_in

        participant = df_p.iloc[0, 0]
        real_start_datetime = df_p.iloc[0, i].split(' ')[1] # datetime
        real_stop_datetime = df_p.iloc[0, i+1].split(' ')[1] # datetime
        real_start = get_sec(real_start_datetime) # datetime in secs
        real_stop = get_sec(real_stop_datetime) # datetime in secs
        start_secs = real_start - substraction # secs from start
        stop_secs = real_stop - substraction # datetime in secs
        duration = stop_secs - start_secs
        room = rooms[int(list(df_p.columns[i])[1])]
        row = [participant , room, start_secs, stop_secs, duration, real_start, real_stop, real_start_datetime, real_stop_datetime]
        rows.append(row)
    
df_timestamps = pd.DataFrame(rows, columns = ['participant','room','start','stop', 'duration', 'start date' , 'stop date', 'start datetime','stop datetime'])

# %%
df_timestamps.set_index(['participant','room'])
# Out:
#                               start  stop  duration  start date  stop date  \
# participant room
# P06PHERAX   Baseline              0   223       223       41084      41307
#             Take-off            542   718       176       41626      41802
#             Savannah            719   798        79       41803      41882
#             Canopy              808  1207       399       41892      42291
#             Bats               1217  1422       205       42301      42506
# ...                             ...   ...       ...         ...        ...
# P18BLAMA    Bats               1067  1136        69       41848      41917
#             Underground        1189  1238        49       41970      42019
#             Grassland          1241  1602       361       42022      42383
#             Sea                1605  1835       230       42386      42616
#             End of the world   1853  2372       519       42634      43153
#
#                              start datetime stop datetime
# participant room
# P06PHERAX   Baseline               11:24:44      11:28:27
#             Take-off               11:33:46      11:36:42
#             Savannah               11:36:43      11:38:02
#             Canopy                 11:38:12      11:44:51
#             Bats                   11:45:01      11:48:26
# ...                                     ...           ...
# P18BLAMA    Bats                   11:37:28      11:38:37
#             Underground            11:39:30      11:40:19
#             Grassland              11:40:22      11:46:23
#             Sea                    11:46:26      11:50:16
#             End of the world       11:50:34      11:59:13
#
# [252 rows x 7 columns]

# %%
df_timestamps
# Out:
#     participant              room  start  stop  duration  start date  \
# 0     P06PHERAX          Baseline      0   223       223       41084
# 1     P06PHERAX          Take-off    542   718       176       41626
# 2     P06PHERAX          Savannah    719   798        79       41803
# 3     P06PHERAX            Canopy    808  1207       399       41892
# 4     P06PHERAX              Bats   1217  1422       205       42301
# ..          ...               ...    ...   ...       ...         ...
# 247    P18BLAMA              Bats   1067  1136        69       41848
# 248    P18BLAMA       Underground   1189  1238        49       41970
# 249    P18BLAMA         Grassland   1241  1602       361       42022
# 250    P18BLAMA               Sea   1605  1835       230       42386
# 251    P18BLAMA  End of the world   1853  2372       519       42634
#
#      stop date start datetime stop datetime
# 0        41307       11:24:44      11:28:27
# 1        41802       11:33:46      11:36:42
# 2        41882       11:36:43      11:38:02
# 3        42291       11:38:12      11:44:51
# 4        42506       11:45:01      11:48:26
# ..         ...            ...           ...
# 247      41917       11:37:28      11:38:37
# 248      42019       11:39:30      11:40:19
# 249      42383       11:40:22      11:46:23
# 250      42616       11:46:26      11:50:16
# 251      43153       11:50:34      11:59:13
#
# [252 rows x 9 columns]

# %%
sum(df_timestamps['duration'] < 90)
# Out:
# 10

# %%
df_timestamps[(df_timestamps['duration'] < 90)].drop(columns = ['start','stop','start date','stop date'])
# Out:
#     participant         room  duration start datetime stop datetime
# 2     P06PHERAX     Savannah        79       11:36:43      11:38:02
# 27    P04PROMCH     Baseline         3       10:30:50      10:30:53
# 30    P04PROMCH       Canopy        51       10:46:46      10:47:37
# 74     P23VIVBA     Savannah        37       11:11:10      11:11:47
# 115    P29FICMA          Sea         1       12:13:18      12:13:19
# 164    P09COUAM     Savannah         1       10:26:26      10:26:27
# 239    P13MORMA  Underground        74       10:09:11      10:10:25
# 244    P18BLAMA     Take-off        72       11:28:24      11:29:36
# 247    P18BLAMA         Bats        69       11:37:28      11:38:37
# 248    P18BLAMA  Underground        49       11:39:30      11:40:19

# %%
df_timestamps['duration'].describe()
# Out:
# count     252.000000
# mean      355.293651
# std       239.617110
# min         1.000000
# 25%       210.000000
# 50%       267.000000
# 75%       431.000000
# max      1120.000000
# Name: duration, dtype: float64

# %%
df_timestamps[df_timestamps['duration'] > 600]
# Out:
#     participant              room  start  stop  duration  start date  \
# 6     P06PHERAX         Grassland   1815  2756       941       42899
# 8     P06PHERAX  End of the world   3109  3904       795       44193
# 15    P05PROZEM         Grassland   1955  2978      1023       40999
# 17    P05PROZEM  End of the world   3422  4083       661       42466
# 24    P01PPILNI         Grassland   2341  3357      1016       36313
# 26    P01PPILNI  End of the world   3815  4529       714       37787
# 32    P04PROMCH       Underground   1119  1790       671       38969
# 33    P04PROMCH         Grassland   1795  2748       953       39645
# 35    P04PROMCH  End of the world   3203  3910       707       41053
# 42    P03PBABCO         Grassland   2126  2802       676       38032
# 44    P03PBABCO  End of the world   3647  4767      1120       39553
# 51     P19MONAL         Grassland   1676  2387       711       36436
# 62     P20POUAX  End of the world   2386  3066       680       38126
# 78     P23VIVBA         Grassland   1737  2631       894       41191
# 80     P23VIVBA  End of the world   3062  3753       691       42516
# 89     P21LIYAT  End of the world   3388  4107       719       40699
# 105    P25PEIAN         Grassland   1929  2976      1047       37021
# 114    P29FICMA         Grassland   1881  2645       764       42104
# 116    P29FICMA  End of the world   3784  4546       762       44007
# 123    P28JUDGU         Grassland   1506  2547      1041       40059
# 132    P26BOUME         Grassland   1869  2809       940       37941
# 134    P26BOUME  End of the world   3296  3984       688       39368
# 141    P30BATDI         Grassland   1944  3060      1116       43687
# 143    P30BATDI  End of the world   3451  4181       730       45194
# 150    P08AKKOR         Grassland   1740  2840      1100       36905
# 152    P08AKKOR  End of the world   3312  4080       768       38477
# 159    P07GHOLE         Grassland   2111  3094       983       36146
# 161    P07GHOLE  End of the world   3590  4291       701       37625
# 168    P09COUAM         Grassland   2025  2698       673       38863
# 170    P09COUAM  End of the world   3112  3846       734       39950
# 177    P12BOULI         Grassland   1743  2589       846       41923
# 186    P11KERSA         Grassland   2041  2839       798       40927
# 188    P11KERSA  End of the world   3094  3847       753       41980
# 195    P10LEVVA         Grassland   1643  2674      1031       39452
# 197    P10LEVVA  End of the world   3090  3775       685       40899
# 204    P14BENLA         Grassland   1931  2935      1004       38812
# 206    P14BENLA  End of the world   3409  4122       713       40290
# 213    P15LEPMA         Grassland   1755  2608       853       37783
# 224    P17ETRPA  End of the world   3302  3976       674       43018
# 233    P16MAUAD  End of the world   2790  3455       665       41269
#
#      stop date start datetime stop datetime
# 6        43840       11:54:59      12:10:40
# 8        44988       12:16:33      12:29:48
# 15       42022       11:23:19      11:40:22
# 17       43127       11:47:46      11:58:47
# 24       37329       10:05:13      10:22:09
# 26       38501       10:29:47      10:41:41
# 32       39640       10:49:29      11:00:40
# 33       40598       11:00:45      11:16:38
# 35       41760       11:24:13      11:36:00
# 42       38708       10:33:52      10:45:08
# 44       40673       10:59:13      11:17:53
# 51       37147       10:07:16      10:19:07
# 62       38806       10:35:26      10:46:46
# 78       42085       11:26:31      11:41:25
# 80       43207       11:48:36      12:00:07
# 89       41418       11:18:19      11:30:18
# 105      38068       10:17:01      10:34:28
# 114      42868       11:41:44      11:54:28
# 116      44769       12:13:27      12:26:09
# 123      41100       11:07:39      11:25:00
# 132      38881       10:32:21      10:48:01
# 134      40056       10:56:08      11:07:36
# 141      44803       12:08:07      12:26:43
# 143      45924       12:33:14      12:45:24
# 150      38005       10:15:05      10:33:25
# 152      39245       10:41:17      10:54:05
# 159      37129       10:02:26      10:18:49
# 161      38326       10:27:05      10:38:46
# 168      39536       10:47:43      10:58:56
# 170      40684       11:05:50      11:18:04
# 177      42769       11:38:43      11:52:49
# 186      41725       11:22:07      11:35:25
# 188      42733       11:39:40      11:52:13
# 195      40483       10:57:32      11:14:43
# 197      41584       11:21:39      11:33:04
# 204      39816       10:46:52      11:03:36
# 206      41003       11:11:30      11:23:23
# 213      38636       10:29:43      10:43:56
# 224      43692       11:56:58      12:08:12
# 233      41934       11:27:49      11:38:54

# %%
if save:
    print('SAVE')
    df_timestamps.to_excel('../data/df_timestamps.xlsx')

# %%
fig , ax = plt.subplots(figsize = (15,7))
df_timestamps.groupby('room').mean().sort_values(by = 'start')['duration'].round(1).plot.bar(ax=ax)
ax.set_title('Mean duration by room')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.02, p.get_height() * 1.01))
ax.set_ylabel('Duration [sec]')
ax.set_xlabel('Room label')
# plt.savefig('../figures/barplot_duration_rooms', bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Room label')
