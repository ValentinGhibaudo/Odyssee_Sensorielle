# %%
import numpy as np
import pandas as pd
import json
import neurokit2 as nk

import sys
sys.path.insert(0, "../code")
import transfer

# %matplotlib inline
#%matplotlib widget

# %%
fname = "../data/LOG00002.TXT"

# %%
with open(fname, "r") as file:
    for i in range(2):
        line = file.readline()
header = json.loads(line[1:])
meta = header[next(iter(header))]
meta
# Out:
# {'sensor': ['RAW', 'RAW', 'RAW', 'RAW', 'RAW', 'RAW'],
#  'device name': 'xx:xx:xx:xx:xx:xx',
#  'column': ['nSeq',
#   'I1',
#   'I2',
#   'O1',
#   'O2',
#   'A1',
#   'A2',
#   'A3',
#   'A4',
#   'A5',
#   'A6'],
#  'sync interval': 2,
#  'time': '20:15:34.631',
#  'comments': '',
#  'device connection': 'OpenLog',
#  'channels': [1, 2, 3, 4, 5, 6],
#  'date': '2022-02-01',
#  'mode': 0,
#  'digital IO': [0, 0, 1, 1],
#  'firmware version': 52,
#  'device': 'bitalino_rev',
#  'position': 0,
#  'sampling rate': 1000,
#  'label': ['A1', 'A2', 'A3', 'A4', 'A5', 'A6'],
#  'resolution': [4, 1, 1, 1, 1, 10, 10, 10, 10, 6, 6],
#  'special': ''}

# %%
data = np.loadtxt(fname).T

# %%
#data = data[:,30000:data.shape[1]-30000] # skip the first and last 30 seconds (noise)

# %%
eegL = data[5] # A1
eegR = data[6] # A2
ecg  = data[7] # A3
eda  = data[8] # A4
ppg  = data[9] # A5

# %%
eegL = transfer.EEG(eegL, meta["resolution"][5])
eegR = transfer.EEG(eegL, meta["resolution"][6])
ecg  = transfer.ECG(ecg, meta["resolution"][7])
eda  = transfer.EDA(ecg, meta["resolution"][8])

# %%
signals, info = nk.bio_process(ecg=ecg, ppg=ppg, eda=eda, sampling_rate=meta["sampling rate"])
results = nk.bio_analyze(signals, sampling_rate=meta["sampling rate"])
# Out:
# /Users/mesca/opt/miniconda3/envs/neurokit/lib/python3.9/site-packages/neurokit2/complexity/fractal_higuchi.py:182: NeuroKitWarning: The detected kmax value is 2 or less. The change in HFD values across kmax values is dependent  on the fractal source data and there may be no plateau in this case. Consider choosing a manual kmax value.
#   warn(
# /Users/mesca/opt/miniconda3/envs/neurokit/lib/python3.9/site-packages/neurokit2/complexity/fractal_higuchi.py:182: NeuroKitWarning: The detected kmax value is 2 or less. The change in HFD values across kmax values is dependent  on the fractal source data and there may be no plateau in this case. Consider choosing a manual kmax value.
#   warn(

# %%
results
# Out:
#    ECG_Rate_Mean  HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  \
# 0      78.434526  767.446512  130.197461   84.797579   88.214684   83.776587
#
#    HRV_SDNNI2  HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD  ...  HRV_SampEn  \
# 0  100.607941         NaN         NaN  103.805854  ...     0.57697
#
#    HRV_ShanEn  HRV_FuzzyEn   HRV_MSE  HRV_CMSE  HRV_RCMSE    HRV_CD   HRV_HFD  \
# 0    8.387231     0.595206  0.428355    0.6886   0.675132  0.425292  1.927459
#
#     HRV_KFD   HRV_LZC
# 0  2.069936  0.657627
#
# [1 rows x 158 columns]

# %%
nk.eda_plot(signals)

# %%
nk.ecg_plot(signals)

# %%
nk.ppg_plot(signals)

# %%
# ECG sitting
signals["ECG_Clean"][10000:20000].plot()
# Out:
# <AxesSubplot:>

# %%
# ECG walking
signals["ECG_Clean"][400000:410000].plot()
# Out:
# <AxesSubplot:>

# %%
# PPG sitting
signals["PPG_Clean"][10000:20000].plot()
# Out:
# <AxesSubplot:>

# %%
# PPG walking
signals["PPG_Clean"][400000:410000].plot()
# Out:
# <AxesSubplot:>

# %%
# Raw EEG sitting
pd.DataFrame(eegL[10000:11000]).plot()
# Out:
# <AxesSubplot:>

# %%
# Raw EEG walking
pd.DataFrame(eegL[400000:401000]).plot()
# Out:
# <AxesSubplot:>
